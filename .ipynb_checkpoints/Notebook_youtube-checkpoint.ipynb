# %% [markdown]
# <div style=" background-color: RGB(0,150,250);" >
# <h2 style="margin: auto; padding: 20px 0; color:#fff; text-align: center">Data Science
# </h2>
# </div>

# %% [markdown]
# # Installation des bibliothèques

# %%
# !pip install nltk

# %% [markdown]
# ### - Import des librairies

# %%
import pandas as pd
import re
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# ### - Chargement du dataframe

# %%
df_ytube = pd.read_csv("youtubeSpamCollection.csv")

# %% [markdown]
# ### - Affichage des 05 premières lignes

# %%
df_ytube.head()
# Out:
#                                     COMMENT_ID            AUTHOR  \
# 0  LZQPQhLyRh80UYxNuaDWhIGQYNQ96IuCg-AYWqNPjpU         Julius NM
# 1  LZQPQhLyRh_C2cTtd9MvFRJedxydaVW-2sNg5Diuo4A       adam riyati
# 2  LZQPQhLyRh9MSZYnf8djyk0gEF9BHDPYrrK-qCczIY8  Evgeny Murashkin
# 3          z13jhp0bxqncu512g22wvzkasxmvvzjaz04   ElNino Melendez
# 4          z13fwbwp1oujthgqj04chlngpvzmtt3r3dw            GsMega
#
#                   DATE                                            CONTENT  \
# 0  2013-11-07T06:20:48  Huh, anyway check out this you[tube] channel: ...
# 1  2013-11-07T12:37:15  Hey guys check out my new channel and our firs...
# 2  2013-11-08T17:34:21             just for test I have to say murdev.com
# 3  2013-11-09T08:28:43   me shaking my sexy ass on my channel enjoy ^_^ ﻿
# 4  2013-11-10T16:05:38            watch?v=vtaRGgvGtWQ   Check this out .﻿
#
#    CLASS
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %% [markdown]
# ### - Affichage des 05 dernières lignes

# %%
df_ytube.tail()
# Out:
#                                        COMMENT_ID                AUTHOR  \
# 1951  _2viQ_Qnc6-bMSjqyL1NKj57ROicCSJV5SwTrw-RFFA          Katie Mettam
# 1952  _2viQ_Qnc6-pY-1yR6K2FhmC5i48-WuNx5CumlHLDAI  Sabina Pearson-Smith
# 1953  _2viQ_Qnc6_k_n_Bse9zVhJP8tJReZpo8uM2uZfnzDs         jeffrey jules
# 1954  _2viQ_Qnc6_yBt8UGMWyg3vh0PulTqcqyQtdE7d4Fl0        Aishlin Maciel
# 1955  _2viQ_Qnc685RPw1aSa1tfrIuHXRvAQ2rPT9R06KTqA           Latin Bosch
#
#                             DATE  \
# 1951  2013-07-13T13:27:39.441000
# 1952  2013-07-13T13:14:30.021000
# 1953  2013-07-13T12:09:31.188000
# 1954  2013-07-13T11:17:52.308000
# 1955  2013-07-12T22:33:27.916000
#
#                                                 CONTENT  CLASS
# 1951  I love this song because we sing it at Camp al...      0
# 1952  I love this song for two reasons: 1.it is abou...      0
# 1953                                                wow      0
# 1954                            Shakira u are so wiredo      0
# ...

# %% [markdown]
# ### - Affichage des statistiques descriptives

# %%
df_ytube.describe()
# Out:
#              CLASS
# count  1956.000000
# mean      0.513804
# std       0.499937
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %% [markdown]
# ### - Nettoyage des données

# %% [markdown]
# * liste des colonnes contenant les valeurs manquantes

# %%
cols_to_fill = ["AUTHOR","CONTENT"]

# %% [markdown]
# * On remplace les valeurs manquantes NaN par "autres"

# %%
df_ytube[cols_to_fill] = df_ytube[cols_to_fill].fillna("autres")

# %% [markdown]
# * On vérifie le nombre de classes qu'il existe plusieurs classes

# %%
print(df_ytube["CLASS"].value_counts())
# Out:
# CLASS
# 1    1005
# 0     951
# Name: count, dtype: int64

# %% [markdown]
# ### - Préparation des données pour la vectorisation

# %%
# on importe la classe TfidfVectorizer de scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer

X = df_ytube["CONTENT"]   # ou la colonne texte pertinente
y = df_ytube["CLASS"]

tfidf = TfidfVectorizer(max_features=300)
X_tfidf = tfidf.fit_transform(X)

# %% [markdown]
# ### - Séparation des données en données d'entraînement et données de test

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf, y, test_size=0.2, random_state=42, stratify=y
)

print(y_train.value_counts())
print(y_test.value_counts())
# Out:
# CLASS
# 1    804
# 0    760
# Name: count, dtype: int64
# CLASS
# 1    201
# 0    191
# Name: count, dtype: int64

# %% [markdown]
# ### - Normalisation

# %%
from sklearn.preprocessing import MaxAbsScaler

sc = MaxAbsScaler()
X_train = sc.fit_transform(X_train)
X_test  = sc.transform(X_test)

# %% [markdown]
# ### - Modélisation

# %%
from sklearn.linear_model import LogisticRegression

model_lr = LogisticRegression(max_iter=1000)
model_lr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# ### - Prédiction

# %%
y_pred = model_lr.predict(X_test)

# %% [markdown]
# ### - Accuracy

# %%
from sklearn.metrics import accuracy_score
print("Accuracy :", accuracy_score(y_test, y_pred))
# Out:
# Accuracy : 0.9489795918367347

# %% [markdown]
# ## Metrics d'évaluation d'un modèle de classification

# %% [markdown]
# ### - classification report

# %%
from sklearn.metrics import classification_report
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95       191
#            1       0.95      0.95      0.95       201
#
#     accuracy                           0.95       392
#    macro avg       0.95      0.95      0.95       392
# weighted avg       0.95      0.95      0.95       392

# %% [markdown]
# ### - Confusion Matrix

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
# Confusion Matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test,y_pred))
# Out:
# Confusion Matrix:
# [[182   9]
#  [ 11 190]]

# %%
pip install joblib

# %%
import joblib 
reviews_model='logistic_regression_model.sav'
joblib.dump(model_lr, reviews_model)
# Out:
# ['logistic_regression_model.sav']

# %%
# Enregistrement du scaler ajusté
scaler_filename='standard_scaler.sav'
joblib.dump(sc, scaler_filename)
print('Modèle et Scaler enregistrés avec succés')
# Out:
# Modèle et Scaler enregistrés avec succés
